# %% [markdown]
# **Глава 4. Модели камер и дополненная реальность**
#
# Навигация к соседним тетрадям:
# <!--NAVIGATION-->
# <[Глава 3. Преобразования изображений](3_image_to_image_mapping.ipynb) | [Содержание](0_index.ipynb) | [Глава 5. Многовидовая геометрия](5_multiple_view_geometry.ipynb)>
#
# <a href="https://colab.research.google.com/github/mualal/computer-vision-with-python/blob/master/notebooks/4_camera_models_and_augmented_reality.ipynb">    <img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Открыть и запустить в Google Colaboratory"></a>

# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
try:
    import google.colab, sys
    # !git clone https://github.com/mualal/computer-vision-with-python.git
    sys.path.append('computer-vision-with-python')
    # %cd computer-vision-with-python
except:
    import sys
    sys.path.append('..')

# %%
import sys
current_dir = os.path.abspath('')
parent_dir = os.path.dirname(current_dir)
sys.path.append(parent_dir)

from improlib import camera

# %%
# загружаем точки из файла
points = np.loadtxt(os.path.join(parent_dir, 'images_input', 'house.p3d')).T
points = np.vstack((points, np.ones(points.shape[1])))

# настраиваем камеру
p = np.hstack((np.eye(3), np.array([[0], [0], [-10]])))
cam = camera.Camera(p)

# проекция
x = cam.project(points)

# изображаем проекцию на графике
plt.figure()
plt.plot(x[0], x[1], 'k.')
plt.show()

# %%
r = 0.05 * np.random.rand(3)
rot = camera.rotation_matrix(r)

plt.figure()
for t in range(20):
    cam.p = np.dot(cam.p, rot)
    x = cam.project(points)
    plt.plot(x[0], x[1], 'k.', markersize=2)
plt.show()

# %% [markdown]
# <!--NAVIGATION-->
# <[Глава 3. Преобразования изображений](3_image_to_image_mapping) | [Содержание](0_index.ipynb) | [Глава 5. Многовидовая геометрия](5_multiple_view_geometry.ipynb)>
#
# <a href="https://colab.research.google.com/github/mualal/computer-vision-with-python/blob/master/notebooks/4_camera_models_and_augmented_reality.ipynb">    <img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Открыть и запустить в Google Colaboratory"></a>
